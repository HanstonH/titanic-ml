# %%
import numpy as np 
import pandas as pd 
import os

TITANIC_DATA_PATH = "train.csv"

titanic_dataset = pd.read_csv(TITANIC_DATA_PATH)

# %% [markdown]
# ## Learning the dataset

# %%
titanic_dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib.pyplot as plt
titanic_dataset.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ## Processing and deleting some unimportant data

# %%
def simplify_title(title):
    if title in ['Mlle', 'Ms']:
        return 'Miss'
    elif title == 'Mme':
        return 'Mrs'
    else:
        return 'Rare'

# %%
def preprocess(data):
    # Drop unnecesary data
    data.drop(columns=['Ticket'], inplace=True)
    data.drop(columns=['Cabin'], inplace=True)

    # Change name into title
    data['Title'] = data['Name'].str.extract(r',\s*([^\.]+)\.', expand=False)
    data['Title'] = data['Title'].apply(simplify_title)
    data.drop(columns=['Name'], inplace=True)

# %%
preprocess(titanic_dataset)

# %%
titanic_dataset.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked Title
# 0        S    Mr
# 1        C   Mrs
# 2        S  Miss
# 3        S   Mrs
# 4        S    Mr

# %% [markdown]
# ## Separating data and label

# %%
titanic_dataset_prepared = titanic_dataset.drop("Survived", axis=1)
titanic_dataset_label = titanic_dataset["Survived"].copy()
titanic_dataset_label
# Out:
# 788    1
# 347    1
# 629    0
# 734    0
# 106    1
#       ..
# 263    0
# 628    0
# 711    0
# 453    1
# 261    1
# Name: Survived, Length: 712, dtype: int64

# %%
titanic_dataset_prepared
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare Embarked   Title
# 788          789       3    1   1.0      1      2  20.5750        S  Master
# 347          348       3    0   NaN      1      0  16.1000        S     Mrs
# 629          630       3    1   NaN      0      0   7.7333        Q      Mr
# 734          735       2    1  23.0      0      0  13.0000        S      Mr
# 106          107       3    0  21.0      0      0   7.6500        S    Miss
# ..           ...     ...  ...   ...    ...    ...      ...      ...     ...
# 263          264       1    1  40.0      0      0   0.0000        S      Mr
# 628          629       3    1  26.0      0      0   7.8958        S      Mr
# 711          712       1    1   NaN      0      0  26.5500        S      Mr
# 453          454       1    1  49.0      1      0  89.1042        C      Mr
# 261          262       3    1   3.0      4      2  31.3875        S  Master
#
# [712 rows x 9 columns]

# %% [markdown]
# ## Splitting the data stratisfiedly, based on survivors

# %%
titanic_dataset['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=1, test_size = 0.2, random_state=42)
for train_index, test_index in sss.split(titanic_dataset, titanic_dataset["Sex"]):
    strat_train_set = titanic_dataset.loc[train_index]
    strat_test_set = titanic_dataset.loc[test_index]

# %%
strat_test_set['Sex'].value_counts()
# Out:
# Sex
# male      116
# female     63
# Name: count, dtype: int64

# %%
titanic_dataset = strat_train_set.copy()

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 788 to 261
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Survived     712 non-null    int64
#  2   Pclass       712 non-null    int64
#  3   Sex          712 non-null    object
#  4   Age          578 non-null    float64
#  5   SibSp        712 non-null    int64
#  6   Parch        712 non-null    int64
#  7   Fare         712 non-null    float64
#  8   Embarked     710 non-null    object
#  9   Title        712 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 61.2+ KB

# %% [markdown]
# ## TURNING SEX NUMBER AND SEPARATING NUM AND NON-NUM

# %%
titanic_dataset.head()
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 788          789         1       3    male   1.0      1      2  20.5750
# 347          348         1       3  female   NaN      1      0  16.1000
# 629          630         0       3    male   NaN      0      0   7.7333
# 734          735         0       2    male  23.0      0      0  13.0000
# 106          107         1       3  female  21.0      0      0   7.6500
#
#     Embarked   Title
# 788        S  Master
# 347        S     Mrs
# 629        Q      Mr
# 734        S      Mr
# 106        S    Miss

# %%
titanic_dataset['Sex'] = (
    titanic_dataset['Sex']
    .str.strip()
    .str.lower()
    .map({'male': 1, 'female': 0})
)

# %% [markdown]
# ## Standardization

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scaler', StandardScaler())
])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
num_attribs = titanic_dataset_prepared.select_dtypes(include="number").columns
cat_attribs = ["Embarked", "Title"]

full_pipeline = ColumnTransformer([
    ("num", num_pipeline, num_attribs),
    ("cat", OneHotEncoder(handle_unknown="ignore"), cat_attribs)
])

titanic_dataset_train = full_pipeline.fit_transform(titanic_dataset_prepared)
titanic_dataset_train
# Out:
# array([[ 1.3225457 ,  0.80807448,  0.73788112, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.39609704,  0.80807448, -1.35523186, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.702899  ,  0.80807448,  0.73788112, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.02246522, -1.57926589,  0.73788112, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.01700077, -1.57926589,  0.73788112, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.73125185,  0.80807448,  0.73788112, ...,  0.        ,
#          0.        ,  0.        ]], shape=(712, 16))

# %%
titanic_dataset = pd.DataFrame(
    titanic_dataset_train, columns= full_pipeline.get_feature_names_out(), index=titanic_dataset_prepared.index
)
titanic_dataset
# Out:
#      num__PassengerId  num__Pclass  num__Sex  num__Age  num__SibSp  \
# 788          1.322546     0.808074  0.737881 -2.157097    0.408878
# 347         -0.396097     0.808074 -1.355232 -0.109664    0.408878
# 629          0.702899     0.808074  0.737881 -0.109664   -0.492426
# 734          1.112100    -0.385596  0.737881 -0.488818   -0.492426
# 106         -1.335310     0.808074 -1.355232 -0.640480   -0.492426
# ..                ...          ...       ...       ...         ...
# 263         -0.723458    -1.579266  0.737881  0.800306   -0.492426
# 628          0.699002     0.808074  0.737881 -0.261326   -0.492426
# 711          1.022465    -1.579266  0.737881 -0.109664   -0.492426
# 453          0.017001    -1.579266  0.737881  1.482784    0.408878
# 261         -0.731252     0.808074  0.737881 -2.005435    3.112790
#
#      num__Parch  num__Fare  cat__Embarked_C  cat__Embarked_Q  cat__Embarked_S  \
# 788    2.026471  -0.241462              0.0              0.0              1.0
# 347   -0.465493  -0.342373              0.0              0.0              1.0
# 629   -0.465493  -0.531041              0.0              1.0              0.0
# 734   -0.465493  -0.412278              0.0              0.0              1.0
# 106   -0.465493  -0.532920              0.0              0.0              1.0
# ..          ...        ...              ...              ...              ...
# 263   -0.465493  -0.705427              0.0              0.0              1.0
# 628   -0.465493  -0.527377              0.0              0.0              1.0
# 711   -0.465493  -0.106726              0.0              0.0              1.0
# 453   -0.465493   1.303866              1.0              0.0              0.0
# 261    2.026471   0.002359              0.0              0.0              1.0
#
#      cat__Embarked_nan  cat__Title_Master  cat__Title_Miss  cat__Title_Mr  \
# 788                0.0                1.0              0.0            0.0
# 347                0.0                0.0              0.0            0.0
# 629                0.0                0.0              0.0            1.0
# 734                0.0                0.0              0.0            1.0
# 106                0.0                0.0              1.0            0.0
# ..                 ...                ...              ...            ...
# 263                0.0                0.0              0.0            1.0
# 628                0.0                0.0              0.0            1.0
# 711                0.0                0.0              0.0            1.0
# 453                0.0                0.0              0.0            1.0
# 261                0.0                1.0              0.0            0.0
#
#      cat__Title_Mrs  cat__Title_Rare
# 788             0.0              0.0
# 347             1.0              0.0
# 629             0.0              0.0
# 734             0.0              0.0
# 106             0.0              0.0
# ..              ...              ...
# 263             0.0              0.0
# 628             0.0              0.0
# 711             0.0              0.0
# 453             0.0              0.0
# 261             0.0              0.0
#
# [712 rows x 16 columns]

# %%
titanic_dataset.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'num__PassengerId'}>,
#         <Axes: title={'center': 'num__Pclass'}>,
#         <Axes: title={'center': 'num__Sex'}>,
#         <Axes: title={'center': 'num__Age'}>],
#        [<Axes: title={'center': 'num__SibSp'}>,
#         <Axes: title={'center': 'num__Parch'}>,
#         <Axes: title={'center': 'num__Fare'}>,
#         <Axes: title={'center': 'cat__Embarked_C'}>],
#        [<Axes: title={'center': 'cat__Embarked_Q'}>,
#         <Axes: title={'center': 'cat__Embarked_S'}>,
#         <Axes: title={'center': 'cat__Embarked_nan'}>,
#         <Axes: title={'center': 'cat__Title_Master'}>],
#        [<Axes: title={'center': 'cat__Title_Miss'}>,
#         <Axes: title={'center': 'cat__Title_Mr'}>,
#         <Axes: title={'center': 'cat__Title_Mrs'}>,
#         <Axes: title={'center': 'cat__Title_Rare'}>]], dtype=object)

# %% [markdown]
# ## Training a model (Decision Tree)

# %%
# # Okay maybe let's not use linear regression, since the result it's not regression type it's classification
from sklearn.linear_model import LinearRegression
# # titanic_dataset_prepared dataset buat latihan
# # titanic_dataset_label buat label
lin_reg = LinearRegression()
lin_reg.fit(titanic_dataset, titanic_dataset_label)
# Out:
# LinearRegression()

# %%
from sklearn.tree import DecisionTreeClassifier

tree_class = DecisionTreeClassifier()
tree_class.fit(titanic_dataset, titanic_dataset_label)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier

rd_forest = RandomForestClassifier()
rd_forest.fit(titanic_dataset, titanic_dataset_label)
# Out:
# RandomForestClassifier()

# %%
some_data = titanic_dataset.iloc[:5]
some_labels = titanic_dataset_label.iloc[:5]

print("Predictions:", tree_class.predict(some_data))
print("Labels: ", list(some_labels))
# some_data_prepared = full_pipeline.transform(some_data)
# Out:
# Predictions: [1 1 0 0 1]
# Labels:  [1, 1, 0, 0, 1]

# %% [markdown]
# ### This is overfitting, since we are training and model evaluating using the same data

# %% [markdown]
# ## Cross Validating with every model

# %%
from sklearn.model_selection import cross_val_score

dec_tree_scores = cross_val_score(tree_class, titanic_dataset, titanic_dataset_label, scoring="accuracy", cv=8)
print("Scores:", dec_tree_scores)
# Out:
# Scores: [0.76404494 0.75280899 0.68539326 0.68539326 0.7752809  0.7752809
#  0.73033708 0.82022472]

# %%
from sklearn.model_selection import cross_val_score

rd_scores = cross_val_score(tree_class, titanic_dataset, titanic_dataset_label, scoring="accuracy", cv=8)
print("Scores:", rd_scores)
# Out:
# Scores: [0.76404494 0.76404494 0.68539326 0.68539326 0.74157303 0.75280899
#  0.74157303 0.83146067]
